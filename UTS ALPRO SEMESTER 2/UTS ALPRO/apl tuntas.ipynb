# %%
#Napi()
#sorting berdasar tahun, kemudian nama
#https://www.programiz.com/dsa/insertion-sort
import pandas as pd
import numpy as np
file=[['Drajad Adhyaksa','Korupsi',2019],
    ['Mirma Fadjarwati Malik','Korupsi',2010],
    ['Ida Lidia Sirnawati','Korupsi',2017],
    ['Uji Naruji','Korupsi',2010],
    ['Andhy Krisnapati','Korupsi',2010],
    ['Ahmad Bazury','Korupsi',2016],
    ['Saikam','Korupsi',2016],
    ['Nova Trianda Saputra','Korupsi',2011],
    ['Khossan Katsidi','Korupsi',2020],
    ['Syachrul','Korupsi',2011],
    ['Eni Maulani Saragih','Korupsi',2019],
    ['Sujasman S Nongke','Korupsi',2017],
    ['Joresmin Nuryadin','Korupsi',2018],
    ['Edi Santoni','Korupsi',2014],
    ['Rosmen','Korupsi',2014],
    ['Edy Sumarno','Korupsi',2014],
    ['Heriyadi','Korupsi',2014],
    ['Satriawan Sulaksono','Korupsi',2018],
    ['Mohammad Reza Pahlevi','Korupsi',2013],
    ['Sentot Lamidi','Korupsi',2013],
    ['Piator Simbolon','Korupsi',2013],
    ['Dharana Herlambang Parikesit','Korupsi',2014],
    ['Upik Rosalina Wasrin','Korupsi',2014],
    ['Herman Sudianto','Korupsi',2019],
    ['Imran bin Mohammed Zein','Terorisme',2015],
    ['Salman Hafidz','Terorisme',2015],
    ['Maman Kusmayadi','Terorisme',2014],
    ['Amrozi','Terorisme',2016],
    ['Imam Samudra','Terorisme',2015],
    ['Mukhlas','Terorisme',2017],
    ['Aman Abdurrahman','Terorisme',2013],
    ['Khanon Wibawa','Pembunuhan',2020],
    ['Sulkhan','Pembunuhan',2019],
    ['Agus Gholib','Pembunuhan',2020],
    ['Selamet','Pembunuhan',2021],
    ['Sarimin','Pembunuhan',2013],
    ['Budi','Pembunuhan',2014],
    ['Aggy','Pembunuhan',2015],
    ['Agung','Pembunuhan',2014],
    ['Robi Moko','Pembunuhan',2018],
    ['Kelik','Pembunuhan',2015],
    ['Muhammad Imron','Pembunuhan',2016],
    ['Andre Adi','Pembunuhan',2019],
    ['Priyanto','Pembunuhan',2017],
    ['Fini Supriyadi','Pembunuhan',2017],
    ['Muhammad Seaful','Peredaran Narkotika',2019],
    ['Yudianto','Peredaran Narkotika',2019],
    ['Eko Danang','Peredaran Narkotika',2018],
    ['Ahmad Taslim','Peredaran Narkotika',2016],
    ['Eko Ribut','Peredaran Narkotika',2018],
    ['Wahyono','Peredaran Narkotika',2019],
    ['Selamet Pilih','Peredaran Narkotika',2016],
    ['Kisworo','Peredaran Narkotika',2017],
    ['Ahmad Syaifudin','Peredaran Narkotika',2018]]
def sorting(file,x):
    for i in range(1,len(file)):
        key = file[i]
        j = i - 1  
        while (j >= 0) and (key[x]< file[j][x]):
            file.insert(j+2,file[j])
            file.pop(j)
            j = j - 1
        file.insert(j+2,key)
        file.pop(j+1)
    return file
file=sorting(file,2)
unique=np.unique(np.array(file)[:,2])
fileasli=[]
for i in unique:
    filesementara=[]
    a=0
    while a<len(file):
        if file[a][2]==int(i):
            filesementara.append(file[a]) 
        a+=1
    filesementara=sorting(filesementara,0)
    sorting(filesementara,0)
    for v in filesementara:
        v.append(int(str(i)[2:]+'0'+str(filesementara.index(v))))
        fileasli.append(v)
print(pd.DataFrame(np.array(fileasli)))
Ask=int(input("Masukan id yang ingin anda cari: "))
# https://www.techiedelight.com/interpolation-search/
def interpolationSearch(A, target):
    if not A:
        return -1
    (left, right) = (0, len(A) - 1)
    while A[right] != A[left] and A[left] <= target <= A[right]:
        mid = left + (target - A[left]) * (right - left) // (A[right] - A[left])
        if target == A[mid]:
            return mid
        elif target < A[mid]:
            right = mid - 1
        else:
            left = mid + 1
    if target == A[left]:
        return left
    return -1
id=[int(v) for v in np.array(fileasli)[:,3]]
answer = interpolationSearch(id,Ask)
if answer != -1:
    print('ID Ditemukan pada nomor: ', answer)
    print('Data: ',fileasli[answer])
else:
    print('ID tidak ditemukan')
# Out:
# Running cells with 'Python 3.9.0 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"C:/Users/Reihan Al Sya'Ban/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.9.0 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"C:/Users/Reihan Al Sya'Ban/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'
